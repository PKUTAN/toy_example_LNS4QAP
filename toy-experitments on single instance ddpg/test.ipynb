# %%
import numpy as np

objs = np.load('./obj_10_step_10.npy')

# %%
objs.min()
# Out:
# 34366.0

# %%
objs.mean()
# Out:
# 41827.72

# %%
import matplotlib.pyplot as plt

bin_width = 1000
bins = np.arange(0, max(objs) + bin_width, bin_width)
hist, _ = np.histogram(objs, bins=bins)
plt.bar(range(len(hist)), hist, width=1.0, align='center')
plt.show()
